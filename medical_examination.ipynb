# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('medical_examination.csv')
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
df['overweight'] = np.where((df['weight'] / ((df['height'] / 100) **2)) > 25, 1, 0)
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
df[df['overweight'] == 1]
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          1  20228    1     156    85.0    140     90            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 5          8  21914    1     151    67.0    120     80            2     2
# 6          9  22113    1     157    93.0    130     80            3     1
# 7         12  22584    2     178    95.0    130     90            3     3
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69994  99992  21074    1     165    80.0    150     80            1     1
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
df['cholesterol'] = np.where(df['cholesterol'] == 1, 0 ,1)

# %%
df['gluc'] = np.where(df['gluc'] == 1, 0 ,1)

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
a = pd.melt(df, value_vars=['cholesterol', 'gluc', 'smoke', 'alco', 'active', 'overweight'], id_vars=['cardio'])
a
# Out:
#         cardio     variable  value
# 0            0  cholesterol      0
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 4            0  cholesterol      0
# ...        ...          ...    ...
# 419995       0   overweight      1
# 419996       1   overweight      1
# 419997       1   overweight      1
# 419998       1   overweight      1
# 419999       0   overweight      0
#
# [420000 rows x 3 columns]

# %%
grouped_df = a.groupby(['cardio', 'variable', 'value']).size().reset_index(name='total')
grouped_df
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %%
catplot = sns.catplot(data=grouped_df, x='variable', y='total', hue='value', col='cardio', kind='bar') 
catplot.fig.set_size_inches(15,8)
catplot

# %%
fig = catplot.fig
fig
fig.savefig('catplot.png')

# %%
df2 = df[(df['ap_lo'] <= df['ap_hi']) & 
         df['height'].between(df['height'].quantile(0.025), df['height'].quantile(0.975), inclusive='both') & 
         df['weight'].between(df['weight'].quantile(0.025), df['weight'].quantile(0.975), inclusive='both')].copy()
df2
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            0     0
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
mask = np.triu(df2.corr())
fig, ax = plt.subplots(figsize=(15,12))
ax.set_facecolor("white")
sns.set(font_scale=1.3)
chart = sns.heatmap(df2.corr(), annot=True, mask=mask, fmt=".1f", center = 0.0, 
            cbar_kws={"shrink":0.5, "ticks":[-0.08, 0.00, 0.08, 0.16, 0.24]}, 
            linewidths=1, vmax=0.30, vmin=-0.14
)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
fig.savefig('heatmap.png')

# %%
df2
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            0     0
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...
